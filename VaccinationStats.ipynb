# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimcolakgil/Technical-Questionnaire/blob/main/VaccinationStats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Question 4:** Implement code to fill the missing data.

# %%
# We import our data set into a pandas DataFrame to easily work with.
data_set = pd.read_csv("https://www.piworks.net/Upload/Document/Original/country_vaccination_stats.csv")
data_set
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
countries = data_set.country.unique()#We are extracting the countries.
for i in range(0,60):#Iterating through.
  country_based = data_set.loc[data_set['country'] == countries[i]]#Getting that country related datas.
  val = country_based['daily_vaccinations'].min()#Finding the minimum value of that relevant country.
  if np.isnan(val):#If that country has no valid vaccination number then we should insert 0.
    val = 0
  index = country_based.iloc[0].name#Row number of the first row of that country.
  data_set.iloc[index,2] = val#Insert operation.

# %%
#We can see that we inserted minimum values.
data_set.loc[data_set['country'] == 'Kuwait']
# Out:
#     country        date  daily_vaccinations         vaccines
# 750  Kuwait  12/28/2020                 0.0  Pfizer/BioNTech

# %%
data_set.loc[data_set['country'] == 'Argentina']
# Out:
#       country        date  daily_vaccinations   vaccines
# 0   Argentina  12/29/2020              6483.0  Sputnik V
# 1   Argentina  12/30/2020             15656.0  Sputnik V
# 2   Argentina  12/31/2020             15656.0  Sputnik V
# 3   Argentina    1/1/2021             11070.0  Sputnik V
# 4   Argentina    1/2/2021              8776.0  Sputnik V
# 5   Argentina    1/3/2021              7400.0  Sputnik V
# 6   Argentina    1/4/2021              6483.0  Sputnik V
# 7   Argentina    1/5/2021              7984.0  Sputnik V
# 8   Argentina    1/6/2021              8173.0  Sputnik V
# 9   Argentina    1/7/2021              8363.0  Sputnik V
# 10  Argentina    1/8/2021             10519.0  Sputnik V
# 11  Argentina    1/9/2021             11942.0  Sputnik V
# 12  Argentina   1/10/2021             13365.0  Sputnik V
# 13  Argentina   1/11/2021             14788.0  Sputnik V
# 14  Argentina   1/12/2021             14056.0  Sputnik V
# ...

# %% [markdown]
# # **Question 5:** Implement code to list the top-3 countries with highest median daily vaccination numbers by considering missing values imputed version of dataset

# %%
#We are creating a dictionary to hold country-median pairs.
medians = {}

# %%
for i in range(0,60):#Iterating trough countries.
  country_based = data_set.loc[data_set['country'] == countries[i]]#Getting that country related datas.
  medians[countries[i]] = country_based.median(numeric_only=True).iloc[0]#We are adding country-median pairs into our dictionary.

# %%
#We are sorting our dictionary descending by our values then listing the top 3 countries.
sorted_medians = sorted(medians.items(), key=lambda x:x[1], reverse=True)
sorted_medians[0],sorted_medians[1],sorted_medians[2]
# Out:
# (('United States', 378253.0), ('China', 276786.0), ('India', 173922.0))

# %% [markdown]
# # **Question 6:**What is the number of total vaccinations done on 1/6/2021 (MM/DD/YYYY) by considering missing values imputed version of dataset?

# %%
date_based = data_set.loc[data_set['date'] == '1/6/2021']#Getting that date related datas.
date_based.daily_vaccinations.sum()#Total vaccination on that date.
# Out:
# 1485255.0

# %% [markdown]
# # **Question 7:**If this list would be a database table, please provide SQL query to fill in the missing daily vaccination numbers with discrete median of country as similar to question a.

# %% [markdown]
# ```
# UPDATE vaccination_table
#   SET daily_vaccinations = 0
#   WHERE daily_vaccinations is nan
# UPDATE vaccination_table
#   SET daily_vaccinations = SELECT PERCENTILE_CONT(0.5) WITHIN GROUP(ORDER BY daily_vaccinations) FROM vaccination_table
#   WHERE daily_vaccinations is not nan
# ```
